# %% [markdown]
# # TASK 3

# %% [markdown]
# ### В игре Plants & Gardens каждый месяц проводятся тематические события, ограниченные по времени. В них игроки могут получить уникальные предметы для сада и персонажей, дополнительные монеты или бонусы. Для получения награды требуется пройти ряд уровней за определенное время. С помощью каких метрик можно оценить результаты последнего прошедшего события?
#
# ### Предположим, в другом событии мы усложнили механику событий так, что при каждой неудачной попытке выполнения уровня игрок будет откатываться на несколько уровней назад. Изменится ли набор метрик оценки результата? Если да, то как?

# %% [markdown]
# Оценить результаты ивента с точки зрения геймдизайна можно по воронке уровней, на которых закончили игроки. Возможно какой-то уровень не очень балансный и на нём отваливаются игроки, это можно будет увидеть по бОльшему проценту отвала игроков конкретно на этом уровне
#
# Бизнесовые метрики могут быть следующими:
# 1)DAU, WAU, Stickness и среднее время сессии во время ивента, сравнить с аналогичными метриками за неделю/через неделю после ивента
# 2)Retention, так же сравниваем тех, кто заходил в ивент и аналогичный период на прошлой неделе (или в другой период)
# 3)ARPU, ARPPU. Посмотреть этими метриками сколько люди донатят во время прохождения уровней, вероятно некоторые игроки будут вложить больше денег, чем обычно для прохождения сложных уровней и получения наград за их прохождения
# 4)Можно посмотреть стоимость привлечения новых игроков во время ивента и вне его, поскольку награды могут мотивировать бОльшее количество игроков начать играть после просмотра рекламы, например
# (Было бы круто проводить A/B-тест и смотреть влияние ивента на эти метрики, будет более корректно оценивать эффект ивента таким образом)

# %% [markdown]
# Для усложненной механики все перечисленные метрики выше пригодны. Стоит смотреть не только на каком уровне игроки закончили, но и на каких уровнях проигрывали, так будет понятнее какие уровни оказались слишком сложными и учесть это в будущем.
